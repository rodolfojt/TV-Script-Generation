# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words] #Não entendi essa linha

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random


threshold = 1e-5 # Por que esse valor?

word_counts = Counter(int_words) # Cria um contador para saber a frequência de cada palavra
total_counts = len(int_words)    # Conta o total de palavras no dicionário total_counts 

freqs = {word: count/total_counts for word, count in word_counts.items()} # Não entendi

p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
 
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]# The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0 #If e Else em uma única linha
    stop = idx + R

    target_words = set(words[start:idx] + words[idx+1:stop+1]) # Forma interessante de não usar um For
    
    return list(target_words) #Por que list() ?

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200# Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From C:\Users\Rodolfo\Miniconda3\envs\dlnd\lib\site-packages\tensorflow\python\ops\nn_impl.py:1124: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-12-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# Já existe uma subpasta ou um arquivo checkpoints.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6565 0.4333 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6630 0.4438 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5249 0.4400 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6185 0.4398 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4973 0.4420 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5433 0.4430 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5499 0.4703 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5549 0.4475 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4517 0.4699 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4410 0.4653 sec/batch
# Nearest to see: bamako, constitutional, combating, popperian, cummins, kissed, algebraically, almeida,
# Nearest to people: laterals, sanctuary, coligny, irresistible, ilias, interrelationships, incite, narrowness,
# Nearest to united: singing, hedy, philosophers, incarnation, pinnacle, tomahawk, merger, athabaskan,
# Nearest to nine: t, temporally, populace, nek, relies, centrum, evocation, dostoevsky,
# Nearest to to: hopped, gorgias, potos, strung, alphabetically, brahma, jaguars, salamat,
# Nearest to up: radars, chordates, skids, lesund, records, casts, ambergris, turbulent,
# Nearest to there: valentino, toyota, scotus, khyber, amorphous, advert, autonomy, nay,
# Nearest to most: coping, gervasio, cypher, implicit, regulars, spit, kastrioti, kagoshima,
# Nearest to animals: hamilcar, novi, amount, reciprocation, norad, protocol, prudently, debug,
# Nearest to pressure: liveries, goya, nye, coloureds, dutt, ursinus, parkinson, pleas,
# Nearest to behind: quell, jaap, sorcery, writable, pascual, specialist, delegated, rudy,
# Nearest to discovered: bubble, detectives, nothing, hot, frederik, layoffs, articulatory, relegated,
# Nearest to quite: alliance, continuants, kak, sawn, jermaine, krapina, spaniard, ultramagnetic,
# Nearest to derived: comets, focus, mods, hunted, faustina, jays, kal, trips,
# Nearest to operating: exponential, uke, stifles, deeper, prohibiting, its, yawkey, subculture,
# Nearest to shows: entrusted, phineus, peri, roca, articles, comb, hamel, inh,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5145 0.4514 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3979 0.4378 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3587 0.4405 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2257 0.4362 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1801 0.4376 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1605 0.4569 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1029 0.4360 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0859 0.4419 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0039 0.4346 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9789 0.4418 sec/batch
# Nearest to see: constitutional, commuter, located, combating, francisco, barring, algebraically, pioneers,
# Nearest to people: sanctuary, coligny, laterals, puts, interrelationships, irresistible, faint, mastery,
# Nearest to united: singing, philosophers, incarnation, hedy, merger, tomahawk, allow, coups,
# Nearest to nine: t, populace, temporally, techniques, via, contract, walter, image,
# Nearest to to: hopped, strung, alphabetically, gorgias, psychologists, potos, pulse, jaguars,
# Nearest to up: records, radars, systems, chordates, silver, skids, casts, lesund,
# Nearest to there: autonomy, khyber, asserts, him, toyota, name, refined, letter,
# Nearest to most: implicit, coping, cypher, regulars, complex, gervasio, spit, function,
# Nearest to animals: amount, protocol, hamilcar, novi, wants, reciprocation, download, auditors,
# Nearest to pressure: liveries, therefore, tenets, nye, tyre, currents, parkinson, originally,
# Nearest to behind: quell, jaap, sorcery, writable, specialist, roughly, absolute, pascual,
# Nearest to discovered: nothing, bubble, detectives, hot, pick, articulatory, u, relegated,
# Nearest to quite: alliance, sawn, auto, taught, paradox, targets, unlimited, rubbery,
# Nearest to derived: focus, hunted, comets, inherently, jays, mods, directly, trips,
# Nearest to operating: exponential, its, deeper, welfare, track, stifles, uke, prohibiting,
# Nearest to shows: entrusted, articles, methods, latin, phineus, modern, at, offset,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9411 0.4486 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8832 0.4415 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8499 0.4362 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8737 0.4462 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8139 0.4497 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8488 0.4395 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7769 0.4647 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8019 0.4349 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7634 0.4373 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7557 0.4364 sec/batch
# Nearest to see: constitutional, commuter, combating, algebraically, located, barring, francisco, kathy,
# Nearest to people: sanctuary, coligny, laterals, puts, irresistible, interrelationships, mastery, diagonal,
# Nearest to united: singing, incarnation, philosophers, hedy, pinnacle, coups, merger, owner,
# Nearest to nine: populace, indiana, walter, conch, temporally, francis, t, centrum,
# Nearest to to: hopped, strung, psychologists, gorgias, alphabetically, pulse, questions, brahma,
# Nearest to up: radars, records, turbulent, casts, discretion, chordates, skids, lesund,
# Nearest to there: khyber, autonomy, valentino, toyota, asserts, laura, scotus, debugging,
# Nearest to most: implicit, coping, spit, cypher, complex, regulars, social, voluntary,
# Nearest to animals: amount, protocol, hamilcar, reciprocation, sinned, novi, plenipotentiary, dioscorus,
# Nearest to pressure: liveries, therefore, nye, tenets, currents, parkinson, tyre, petrochemical,
# Nearest to behind: quell, jaap, writable, specialist, sorcery, delegated, honda, plymouth,
# Nearest to discovered: bubble, nothing, detectives, hot, pick, frederik, layoffs, relegated,
# Nearest to quite: alliance, spaniard, auto, taught, unlimited, rubbery, targets, sawn,
# Nearest to derived: focus, hunted, comets, inherently, mods, trips, jays, vandalism,
# Nearest to operating: exponential, welfare, its, trolltech, track, prohibiting, deeper, stifles,
# Nearest to shows: entrusted, articles, methods, phineus, latin, modern, offset, at,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7757 0.4696 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7390 0.4901 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7199 0.4865 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7167 0.4781 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7031 0.4793 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7013 0.4718 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7034 0.4755 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7256 0.4416 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7146 0.4520 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6675 0.5179 sec/batch
# Nearest to see: constitutional, combating, located, commuter, algebraically, airspace, popperian, adequate,
# Nearest to people: laterals, sanctuary, irresistible, coligny, narrowness, puts, interrelationships, ilias,
# Nearest to united: hedy, incarnation, singing, philosophers, outbreak, coups, pinnacle, tomahawk,
# Nearest to nine: seaman, populace, walter, indiana, two, francis, eight, conch,
# Nearest to to: hopped, gorgias, psychologists, pulse, strung, brahma, alphabetically, greenberg,
# Nearest to up: radars, chordates, turbulent, skids, records, casts, lesund, discretion,
# Nearest to there: valentino, laura, propeller, khyber, amorphous, asserts, scotus, toyota,
# Nearest to most: coping, complex, voroshilov, intra, spit, social, regulars, implicit,
# Nearest to animals: amount, dioscorus, protocol, hamilcar, reciprocation, novi, plenipotentiary, sinned,
# Nearest to pressure: liveries, nye, therefore, tenets, currents, parkinson, pleas, goya,
# Nearest to behind: quell, jaap, writable, delegated, honda, specialist, sorcery, jellyfish,
# Nearest to discovered: bubble, nothing, detectives, hot, layoffs, frederik, relegated, pick,
# Nearest to quite: alliance, spaniard, rubbery, sawn, homonyms, auto, taught, aspirations,
# Nearest to derived: focus, hunted, mods, comets, trips, inherently, kal, jays,
# Nearest to operating: exponential, trolltech, welfare, its, deeper, uke, prohibiting, columbine,
# Nearest to shows: entrusted, phineus, articles, methods, comb, hamel, latin, modern,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6905 0.5181 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6999 0.5166 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6433 0.5162 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6482 0.5154 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6223 0.5150 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6452 0.5216 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5881 0.3833 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5412 0.5073 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5124 0.5147 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5010 0.5215 sec/batch
# Nearest to see: constitutional, combating, airspace, located, commuter, kissed, centrifuge, popperian,
# Nearest to people: laterals, sanctuary, narrowness, coligny, puts, irresistible, godless, mastery,
# Nearest to united: hedy, outbreak, headline, incarnation, philosophers, britain, faro, coups,
# Nearest to nine: walter, two, eight, seaman, swimmer, wrestler, francis, indiana,
# Nearest to to: hopped, gorgias, pulse, psychologists, brahma, strung, alphabetically, themas,
# Nearest to up: radars, chordates, skids, records, lesund, casts, turbulent, silver,
# Nearest to there: valentino, laura, amorphous, propeller, toyota, scotus, khyber, asserts,
# Nearest to most: coping, voroshilov, voluntary, snapshots, insurrections, mozilla, gervasio, cypher,
# Nearest to animals: dioscorus, amount, debug, stalker, reciprocation, protocol, sinned, multiplicity,
# Nearest to pressure: liveries, nye, therefore, currents, tenets, parkinson, scoped, metal,
# Nearest to behind: quell, writable, jaap, roundabout, specialist, santer, honda, jellyfish,
# Nearest to discovered: bubble, hot, detectives, nothing, layoffs, frederik, articulatory, pick,
# Nearest to quite: continuants, spaniard, rubbery, ultramagnetic, alliance, sawn, targets, utilitarians,
# Nearest to derived: focus, comets, hunted, kal, mods, faustina, emit, hedmark,
# Nearest to operating: exponential, trolltech, rifle, welfare, its, uke, intonation, stifles,
# Nearest to shows: entrusted, phineus, methods, articles, hamel, comb, latin, peri,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4929 0.5170 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5043 0.4823 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4677 0.5357 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5320 0.5398 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4779 0.4912 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.5012 0.4710 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4528 0.4761 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3831 0.4906 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4165 0.4739 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4123 0.4701 sec/batch
# Nearest to see: constitutional, combating, located, commuter, parseval, algebraically, airspace, centrifuge,
# Nearest to people: laterals, narrowness, basements, mastery, sanctuary, coligny, irresistible, brandished,
# Nearest to united: hedy, britain, ohio, outbreak, faro, philosophers, incline, states,
# Nearest to nine: seaman, walter, two, ted, ohio, allan, zero, swimmer,
# Nearest to to: hopped, pulse, gorgias, psychologists, questions, salamat, if, aegina,
# Nearest to up: radars, chordates, skids, records, lesund, silver, hermit, casts,
# Nearest to there: valentino, laura, propeller, amorphous, compatriots, asserts, debugging, martyrdom,
# Nearest to most: coping, complex, insurrections, mozilla, spit, use, voroshilov, fats,
# Nearest to animals: dioscorus, amount, stalker, debug, sinned, duplicate, multiplicity, protocol,
# Nearest to pressure: liveries, therefore, currents, nye, tenets, generators, scoped, petrochemical,
# Nearest to behind: quell, writable, jaap, roundabout, jellyfish, santer, kariba, delegated,
# Nearest to discovered: bubble, hot, detectives, layoffs, nothing, frederik, goldsmith, articulatory,
# Nearest to quite: continuants, spaniard, rubbery, ultramagnetic, ask, taught, blows, utilitarians,
# Nearest to derived: focus, comets, hunted, kal, mods, technik, faustina, emit,
# Nearest to operating: exponential, trolltech, rifle, welfare, manufacturers, its, uke, leftmost,
# Nearest to shows: entrusted, phineus, hamel, methods, articles, comb, peri, sissy,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4264 0.5060 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4395 0.5039 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4537 0.5121 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3707 0.5158 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4272 0.5201 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4029 0.5043 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3505 0.4954 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3861 0.4870 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4149 0.4428 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3917 0.5177 sec/batch
# Nearest to see: parseval, centrifuge, guid, constitutional, algebraically, reverting, airspace, kissed,
# Nearest to people: laterals, basements, mastery, coligny, narrowness, godless, irresistible, incite,
# Nearest to united: hedy, ohio, britain, liberalisation, states, faro, coups, clippers,
# Nearest to nine: walter, two, allan, seaman, rnson, zero, ted, eight,
# Nearest to to: hopped, gorgias, themas, brahma, if, psychologists, questions, pulse,
# Nearest to up: radars, chordates, skids, lesund, records, silver, casts, turbulent,
# Nearest to there: amorphous, valentino, propeller, laura, compatriots, asserts, debugging, martyrdom,
# Nearest to most: fats, intra, use, coping, insurrections, complex, mozilla, xenophobia,
# Nearest to animals: dioscorus, stalker, amount, debug, reciprocation, multiplicity, protocol, foreskin,
# Nearest to pressure: liveries, currents, therefore, nye, generators, petrochemical, tenets, scoped,
# Nearest to behind: quell, jaap, jellyfish, roundabout, santer, kariba, writable, delegated,
# Nearest to discovered: hot, bubble, detectives, frederik, domo, layoffs, articulatory, hideyoshi,
# Nearest to quite: continuants, rubbery, ultramagnetic, blows, spaniard, homonyms, utilitarians, sawn,
# Nearest to derived: comets, hunted, focus, technik, kal, mods, hedmark, heritages,
# Nearest to operating: trolltech, exponential, manufacturers, track, optic, rifle, its, welfare,
# Nearest to shows: phineus, entrusted, hamel, articles, peri, methods, showings, works,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3570 0.5088 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3892 0.5098 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3637 0.5435 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3900 0.5008 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3758 0.5091 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3516 0.5083 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3693 0.5028 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3941 0.5287 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3566 0.5114 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3371 0.4757 sec/batch
# Nearest to see: parseval, centrifuge, iqs, constitutional, guid, reverting, kissed, ncipe,
# Nearest to people: laterals, mastery, basements, incite, coligny, narrowness, irresistible, godless,
# Nearest to united: states, britain, ohio, liberalisation, faro, hedy, lahore, tomahawk,
# Nearest to nine: two, zero, seaman, walter, eight, morey, rnson, rennie,
# Nearest to to: hopped, gorgias, if, themas, offsets, brahma, equipment, intonation,
# Nearest to up: radars, chordates, lesund, skids, silver, records, transporter, ramjet,
# Nearest to there: amorphous, valentino, laura, compatriots, propeller, asserts, beings, martyrdom,
# Nearest to most: voroshilov, fats, use, longstanding, ern, coping, intra, xenophobia,
# Nearest to animals: dioscorus, stalker, reciprocation, amount, mammals, multiplicity, foreskin, characteristic,
# Nearest to pressure: liveries, currents, therefore, nye, petrochemical, tenets, scoped, pleas,
# Nearest to behind: quell, jaap, roundabout, jellyfish, kariba, excavators, quadrivium, santer,
# Nearest to discovered: hot, bubble, detectives, domo, layoffs, vicissitudes, frederik, hideyoshi,
# Nearest to quite: continuants, rubbery, homonyms, blows, taught, ultramagnetic, utilitarians, sawn,
# Nearest to derived: comets, hunted, focus, hedmark, heritages, mods, shank, technik,
# Nearest to operating: trolltech, exponential, manufacturers, its, proprietary, track, peripherals, congestion,
# Nearest to shows: phineus, hamel, entrusted, peri, methods, showings, articles, sissy,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3164 0.4448 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2759 0.4875 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3898 0.4982 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3907 0.5026 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4084 0.5315 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2842 0.4970 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3152 0.5066 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3558 0.5174 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2018 0.5258 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3119 0.5084 sec/batch
# Nearest to see: parseval, centrifuge, iqs, constitutional, reverting, guid, culture, kissed,
# Nearest to people: laterals, incite, coligny, mastery, narrowness, basements, irresistible, diuretic,
# Nearest to united: states, ohio, britain, hedy, tomahawk, clippers, underdeveloped, icj,
# Nearest to nine: two, zero, eight, one, swimmer, three, walter, rnson,
# Nearest to to: themas, brahma, gorgias, modify, imperiled, hopped, would, offsets,
# Nearest to up: chordates, lesund, skids, radars, records, silver, hermit, transporter,
# Nearest to there: amorphous, valentino, propeller, compatriots, martyrdom, laura, asserts, sti,
# Nearest to most: voroshilov, fats, xenophobia, mozilla, intra, longstanding, ern, complex,
# Nearest to animals: stalker, dioscorus, reciprocation, mammals, multiplicity, hamilcar, foreskin, sinned,
# Nearest to pressure: liveries, currents, therefore, nye, petrochemical, tenets, pleas, scoped,
# Nearest to behind: quell, jellyfish, jaap, roundabout, kariba, delegated, quadrivium, writable,
# Nearest to discovered: hot, bubble, hideyoshi, detectives, vicissitudes, telemachus, layoffs, domo,
# Nearest to quite: continuants, homonyms, rubbery, utilitarians, ultramagnetic, taught, lignin, blows,
# Nearest to derived: comets, hedmark, hunted, heritages, kal, technik, focus, shank,
# Nearest to operating: trolltech, manufacturers, proprietary, exponential, platform, congestion, its, welfare,
# Nearest to shows: hamel, phineus, sissy, showings, campephilus, peri, carmina, works,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3049 0.5498 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3100 0.5603 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3392 0.2528 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2452 0.5291 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2133 0.5218 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2221 0.4663 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2031 0.4885 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1948 0.4874 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2125 0.5744 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1757 0.4978 sec/batch
# Nearest to see: parseval, iqs, centrifuge, reverting, constitutional, culture, founded, guid,
# Nearest to people: incite, laterals, coligny, mastery, narrowness, basements, irresistible, shuffles,
# Nearest to united: states, hedy, britain, tomahawk, ohio, liberalisation, faro, clippers,
# Nearest to nine: two, zero, rnson, three, walter, levine, eight, seaman,
# Nearest to to: themas, modify, brahma, gorgias, imperiled, salamat, would, lease,
# Nearest to up: chordates, radars, lesund, skids, records, lowly, hermit, buddies,
# Nearest to there: amorphous, propeller, beings, asserts, valentino, laura, cartilage, buddhist,
# Nearest to most: voroshilov, mozilla, fats, longstanding, anac, intra, use, insurrections,
# Nearest to animals: mammals, reciprocation, dioscorus, subfamily, treat, hamilcar, stalker, foreskin,
# Nearest to pressure: liveries, therefore, currents, petrochemical, nye, scoped, tenets, ursinus,
# Nearest to behind: quell, roundabout, jaap, jellyfish, kariba, delegated, quadrivium, afford,
# Nearest to discovered: hot, bubble, hideyoshi, vicissitudes, detectives, telemachus, frederik, glaciations,
# Nearest to quite: continuants, homonyms, utilitarians, rubbery, ultramagnetic, lignin, blows, partaking,
# Nearest to derived: comets, hedmark, hunted, shank, heritages, kal, technik, lymphedema,
# Nearest to operating: trolltech, manufacturers, proprietary, platform, exponential, congestion, track, peripherals,
# Nearest to shows: phineus, hamel, peri, sissy, campephilus, showings, carmina, yamada,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2233 0.4721 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2092 0.4619 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1935 0.4895 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1312 0.4703 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1882 0.4697 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1893 0.4652 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1630 0.4609 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1828 0.4679 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1831 0.4909 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.2016 0.4654 sec/batch
# Nearest to see: parseval, centrifuge, iqs, culture, founded, sharers, guid, constitutional,
# Nearest to people: incite, mastery, laterals, coligny, narrowness, irresistible, basements, diuretic,
# Nearest to united: states, britain, hedy, underdeveloped, tomahawk, liberalisation, ohio, faro,
# Nearest to nine: two, zero, rnson, three, walter, eight, levine, five,
# Nearest to to: modify, brahma, themas, gorgias, if, offsets, imperiled, would,
# Nearest to up: radars, chordates, lesund, skids, silver, feats, ramjet, hermit,
# Nearest to there: amorphous, martyrdom, propeller, compatriots, beings, valentino, asserts, debugging,
# Nearest to most: voroshilov, fats, intra, use, longstanding, mozilla, such, anac,
# Nearest to animals: mammals, reciprocation, subfamily, dioscorus, canidae, asymptomatic, treat, foreskin,
# Nearest to pressure: liveries, therefore, currents, petrochemical, sulfur, scoped, pleas, heat,
# Nearest to behind: quell, roundabout, jellyfish, jaap, kariba, team, hines, writable,
# Nearest to discovered: hot, bubble, vicissitudes, telemachus, hideyoshi, frederik, detectives, scandinavians,
# Nearest to quite: continuants, lignin, homonyms, rubbery, partaking, utilitarians, ultramagnetic, sakura,
# Nearest to derived: comets, heritages, hunted, hedmark, kal, tuscan, rebar, shank,
# Nearest to operating: trolltech, manufacturers, proprietary, exponential, its, welfare, track, peripherals,
# Nearest to shows: hamel, phineus, showings, sissy, works, carmina, peri, daniell,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1722 0.4699 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2171 0.4619 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1909 0.4671 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1567 0.4712 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1939 0.4634 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1831 0.4765 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1951 0.4642 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1590 0.4699 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1261 0.4674 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2112 0.4626 sec/batch
# Nearest to see: parseval, culture, centrifuge, iqs, founded, jpeg, guid, ellipse,
# Nearest to people: incite, laterals, coligny, basements, mastery, narrowness, irresistible, diuretic,
# Nearest to united: states, britain, liberalisation, tomahawk, hedy, ohio, underdeveloped, icj,
# Nearest to nine: zero, two, three, five, one, eight, rnson, morey,
# Nearest to to: gorgias, modify, themas, brahma, if, cci, imperiled, enabled,
# Nearest to up: chordates, lesund, radars, transporter, skids, ramjet, hermit, gall,
# Nearest to there: amorphous, martyrdom, beings, buddhist, scotus, laura, valentino, compatriots,
# Nearest to most: voroshilov, use, intra, such, fats, longstanding, ern, mozilla,
# Nearest to animals: mammals, subfamily, reciprocation, asymptomatic, foreskin, canidae, vertebrates, stalker,
# Nearest to pressure: liveries, therefore, currents, petrochemical, pleas, heat, scoped, ursinus,
# Nearest to behind: quell, roundabout, jellyfish, jaap, kariba, quadrivium, writable, afford,
# Nearest to discovered: hot, bubble, vicissitudes, telemachus, frederik, scandinavians, hideyoshi, glaciations,
# Nearest to quite: continuants, homonyms, partaking, lignin, taught, ultramagnetic, rubbery, utilitarians,
# Nearest to derived: comets, heritages, hedmark, hunted, tuscan, kal, rebar, technik,
# Nearest to operating: trolltech, proprietary, manufacturers, exponential, welfare, platform, versions, gyroscope,
# Nearest to shows: hamel, phineus, showings, sissy, carmina, works, peri, genie,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1745 0.4670 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1712 0.4744 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1962 0.4696 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1791 0.4652 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1359 0.4621 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1279 0.4665 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1663 0.4692 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1360 0.4814 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1948 0.4765 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2035 0.4809 sec/batch
# Nearest to see: parseval, culture, iqs, centrifuge, founded, jpeg, deprives, reverting,
# Nearest to people: incite, coligny, mastery, basements, laterals, irresistible, despot, diuretic,
# Nearest to united: states, britain, ohio, liberalisation, hedy, icj, tomahawk, faro,
# Nearest to nine: two, zero, one, three, five, eight, rnson, walter,
# Nearest to to: brahma, gorgias, modify, themas, cci, imperiled, enabled, lease,
# Nearest to up: chordates, lesund, hermit, radars, gall, departs, skids, lowly,
# Nearest to there: amorphous, compatriots, martyrdom, scotus, laura, buddhist, beings, valentino,
# Nearest to most: voroshilov, longstanding, insurrections, such, ern, intra, fats, bleuler,
# Nearest to animals: mammals, subfamily, reciprocation, vertebrates, seals, asymptomatic, canidae, foreskin,
# Nearest to pressure: liveries, therefore, currents, pleas, petrochemical, nye, emden, goya,
# Nearest to behind: quell, roundabout, jaap, jellyfish, quadrivium, delegated, kariba, excavators,
# Nearest to discovered: vicissitudes, bubble, hot, frederik, telemachus, scandinavians, hideyoshi, procuring,
# Nearest to quite: continuants, partaking, homonyms, lignin, rubbery, utilitarians, affordable, blows,
# Nearest to derived: heritages, hedmark, comets, tuscan, hunted, shank, rebar, kal,
# Nearest to operating: trolltech, proprietary, exponential, welfare, manufacturers, its, malthusian, congestion,
# Nearest to shows: sissy, showings, phineus, hamel, carmina, peri, genie, works,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2013 0.4771 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1282 0.4675 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1442 0.4803 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1291 0.4673 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0220 0.4727 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1699 0.4894 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1391 0.4740 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1379 0.4882 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1637 0.1138 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1038 0.5590 sec/batch
# Nearest to see: parseval, culture, founded, iqs, centrifuge, heritage, jpeg, list,
# Nearest to people: incite, diuretic, mastery, coligny, carnivorous, laterals, basements, irresistible,
# Nearest to united: states, britain, ohio, liberalisation, tomahawk, hedy, icj, montr,
# Nearest to nine: zero, two, three, one, eight, five, walter, rnson,
# Nearest to to: modify, themas, gorgias, enabled, cci, brahma, imperiled, crafting,
# Nearest to up: chordates, radars, lesund, ramjet, lowly, feats, transporter, departs,
# Nearest to there: amorphous, martyrdom, sti, laura, buddhist, neophyte, beings, valentino,
# Nearest to most: voroshilov, such, fats, longstanding, uploading, mozilla, intra, use,
# Nearest to animals: subfamily, mammals, reciprocation, vertebrates, seals, asymptomatic, aquatic, canidae,
# Nearest to pressure: liveries, therefore, currents, pleas, admitted, petrochemical, refrigeration, goya,
# Nearest to behind: quell, roundabout, jellyfish, jaap, kariba, shooting, excavators, afford,
# Nearest to discovered: vicissitudes, bubble, hot, hideyoshi, scandinavians, glaciations, telemachus, frederik,
# Nearest to quite: continuants, lignin, homonyms, rubbery, routines, utilitarians, affordable, blows,
# Nearest to derived: heritages, hedmark, tuscan, comets, word, shank, technik, anemones,
# Nearest to operating: trolltech, versions, proprietary, transmeta, exponential, manufacturers, ewing, platform,
# Nearest to shows: sissy, phineus, showings, carmina, genie, hamel, peri, premiered,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0775 0.5233 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0690 0.5287 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1122 0.4946 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0620 0.5849 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0952 0.5443 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0433 0.5414 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1035 0.5139 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0842 0.5343 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1018 0.5247 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0102 0.5519 sec/batch
# Nearest to see: parseval, culture, founded, iqs, jpeg, centrifuge, heritage, ncipe,
# Nearest to people: incite, diuretic, mastery, carnivorous, basements, laterals, coligny, dangers,
# Nearest to united: states, britain, ohio, liberalisation, tomahawk, hedy, icj, montr,
# Nearest to nine: two, zero, three, one, five, eight, walter, levine,
# Nearest to to: modify, cci, themas, imperiled, enabled, brahma, gorgias, lease,
# Nearest to up: lesund, chordates, radars, feats, lowly, ramjet, oui, bpp,
# Nearest to there: laura, get, martyrdom, amorphous, sti, beings, just, average,
# Nearest to most: such, voroshilov, voluntary, salmon, use, longstanding, anac, fats,
# Nearest to animals: subfamily, mammals, reciprocation, dioscorus, taiga, vertebrates, asymptomatic, nesting,
# Nearest to pressure: liveries, therefore, currents, petrochemical, pleas, admitted, refrigeration, tired,
# Nearest to behind: roundabout, quell, jellyfish, jaap, kariba, quadrivium, swelling, excavators,
# Nearest to discovered: vicissitudes, bubble, hot, glaciations, tariff, ignited, hideyoshi, frederik,
# Nearest to quite: continuants, homonyms, affordable, routines, lignin, rubbery, blows, taught,
# Nearest to derived: heritages, hedmark, tuscan, comets, technik, shank, word, hunted,
# Nearest to operating: trolltech, exponential, proprietary, versions, transmeta, ewing, malthusian, platform,
# Nearest to shows: sissy, showings, phineus, carmina, hamel, genie, peri, premiered,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0277 0.4966 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0147 0.4784 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0183 0.4695 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0672 0.4688 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0787 0.4777 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0651 0.4788 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0795 0.5172 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1039 0.4769 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0478 0.4658 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0418 0.4719 sec/batch
# Nearest to see: culture, parseval, founded, jpeg, and, list, iqs, centrifuge,
# Nearest to people: diuretic, incite, basements, mastery, carnivorous, laterals, narrowness, dangers,
# Nearest to united: states, britain, ohio, liberalisation, tomahawk, hedy, icj, faro,
# Nearest to nine: two, three, zero, five, one, eight, walter, levine,
# Nearest to to: modify, gorgias, cci, brahma, imperiled, themas, getting, warlock,
# Nearest to up: lesund, chordates, radars, lowly, gall, bpp, ramjet, skids,
# Nearest to there: martyrdom, laura, beings, amorphous, get, average, sti, compatriots,
# Nearest to most: such, voroshilov, fats, anac, mozilla, intra, noumenon, use,
# Nearest to animals: subfamily, mammals, reciprocation, taiga, nesting, molluscs, canidae, asymptomatic,
# Nearest to pressure: liveries, therefore, currents, petrochemical, pleas, refrigeration, generators, tired,
# Nearest to behind: quell, roundabout, jellyfish, swelling, kariba, jaap, quadrivium, overnight,
# Nearest to discovered: vicissitudes, bubble, glaciations, hot, ignited, frederik, tariff, bernicia,
# Nearest to quite: continuants, homonyms, routines, lignin, affordable, rubbery, underdogs, sakura,
# Nearest to derived: heritages, hedmark, tuscan, comets, shank, word, anemones, technik,
# Nearest to operating: trolltech, proprietary, versions, transmeta, exponential, workgroups, ewing, platform,
# Nearest to shows: sissy, hamel, showings, carmina, phineus, peri, deleting, genie,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0800 0.4689 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0628 0.4642 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0876 0.4739 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0644 0.4704 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0872 0.4725 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0586 0.4645 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.1006 0.4662 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0153 0.4703 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0772 0.4662 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0749 0.4681 sec/batch
# Nearest to see: culture, parseval, founded, jpeg, heritage, ncipe, iqs, wmo,
# Nearest to people: incite, diuretic, carnivorous, mastery, coligny, hiv, basements, tabula,
# Nearest to united: states, britain, liberalisation, tomahawk, ohio, hedy, icj, merger,
# Nearest to nine: zero, two, three, one, five, eight, levine, walter,
# Nearest to to: modify, gorgias, brahma, getting, cci, imperiled, primacy, enabled,
# Nearest to up: lesund, chordates, gall, departs, lowly, bpp, radars, oui,
# Nearest to there: laura, martyrdom, armenian, beings, buddhist, sti, average, fianna,
# Nearest to most: such, fats, voluntary, voroshilov, cumin, connotation, longstanding, anac,
# Nearest to animals: mammals, subfamily, nesting, molluscs, reciprocation, taiga, vertebrates, asymptomatic,
# Nearest to pressure: liveries, therefore, pleas, goya, currents, admitted, tired, refrigeration,
# Nearest to behind: quell, roundabout, jellyfish, delegated, kariba, swelling, funding, jaap,
# Nearest to discovered: vicissitudes, bubble, tariff, scandinavians, frederik, bernicia, telemachus, hot,
# Nearest to quite: continuants, homonyms, partaking, routines, rubbery, lignin, affordable, blows,
# Nearest to derived: heritages, hedmark, tuscan, comets, shank, anemones, hunted, word,
# Nearest to operating: trolltech, versions, transmeta, exponential, proprietary, freebsd, ewing, workgroups,
# Nearest to shows: sissy, showings, phineus, carmina, hamel, peri, genie, premiered,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0545 0.4730 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9973 0.4656 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0384 0.4639 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0776 0.4667 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0766 0.4669 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1064 0.4649 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1404 0.4672 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0493 0.4802 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0334 0.4689 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0870 0.4752 sec/batch
# Nearest to see: culture, parseval, ncipe, founded, jpeg, list, africaine, heritage,
# Nearest to people: incite, hiv, diuretic, carnivorous, coligny, afer, tabula, ncs,
# Nearest to united: states, britain, tomahawk, ohio, liberalisation, hedy, secondhand, arica,
# Nearest to nine: zero, two, three, one, five, eight, four, levine,
# Nearest to to: modify, getting, gorgias, cci, brahma, salamat, nanosystems, themas,
# Nearest to up: lesund, chordates, gall, bpp, lowly, feats, riaa, departs,
# Nearest to there: sti, laura, martyrdom, average, amorphous, beings, get, householder,
# Nearest to most: such, voroshilov, voluntary, noumenon, longstanding, fats, anac, fulham,
# Nearest to animals: mammals, subfamily, nesting, taiga, molluscs, reciprocation, vertebrates, agave,
# Nearest to pressure: liveries, therefore, goya, pleas, refrigeration, admitted, emden, currents,
# Nearest to behind: quell, roundabout, overnight, jellyfish, kariba, lapd, delegated, quadrivium,
# Nearest to discovered: vicissitudes, bubble, tariff, scandinavians, frederik, bernicia, plutarch, telemachus,
# Nearest to quite: continuants, homonyms, routines, rubbery, blows, affordable, lignin, whiteness,
# Nearest to derived: heritages, hedmark, tuscan, word, anemones, comets, hunted, msa,
# Nearest to operating: trolltech, exponential, versions, transmeta, proprietary, jurist, gyroscope, ewing,
# Nearest to shows: sissy, showings, phineus, premiered, carmina, hamel, peri, genie,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9718 0.4688 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0214 0.4664 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0255 0.4901 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0290 0.4837 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0870 0.4598 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0420 0.4435 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9986 0.4610 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9765 0.4624 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0218 0.4594 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9981 0.4648 sec/batch
# Nearest to see: culture, parseval, ncipe, jpeg, founded, list, heritage, disambiguation,
# Nearest to people: incite, diuretic, hiv, carnivorous, afer, tabula, godless, basements,
# Nearest to united: states, britain, secondhand, tomahawk, liberalisation, ohio, hedy, sofa,
# Nearest to nine: three, zero, one, two, five, eight, four, six,
# Nearest to to: modify, catapulted, gorgias, getting, clinched, brahma, cci, themas,
# Nearest to up: lesund, chordates, lowly, bpp, ramjet, feats, systems, departs,
# Nearest to there: sti, laura, just, average, amorphous, martyrdom, armenian, geologically,
# Nearest to most: such, voroshilov, voluntary, noumenon, mozilla, patriarchate, regulars, anac,
# Nearest to animals: mammals, subfamily, nesting, molluscs, taiga, reciprocation, vertebrates, agave,
# Nearest to pressure: liveries, refrigeration, goya, therefore, currents, adiabatic, admitted, pleas,
# Nearest to behind: quell, roundabout, swelling, overnight, jellyfish, jaian, kariba, delegated,
# Nearest to discovered: vicissitudes, bubble, scandinavians, frederik, telemachus, glaciations, tariff, plutarch,
# Nearest to quite: continuants, homonyms, affordable, lignin, rubbery, utilitarians, routines, blows,
# Nearest to derived: heritages, hedmark, tuscan, word, anemones, comets, msa, shank,
# Nearest to operating: trolltech, versions, exponential, transmeta, installs, jurist, gyroscope, workgroups,
# Nearest to shows: sissy, carmina, premiered, showings, phineus, hamel, peri, genie,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9963 0.4794 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9249 0.4601 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0358 0.4726 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9964 0.4588 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9931 0.4594 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9719 0.4610 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9014 0.4699 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9245 0.5049 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9083 0.4577 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9732 0.4674 sec/batch
# Nearest to see: culture, parseval, jpeg, founded, ncipe, a, list, wmo,
# Nearest to people: incite, diuretic, hiv, afer, subdivision, basements, carnivorous, tabula,
# Nearest to united: states, britain, secondhand, hedy, ohio, tomahawk, liberalisation, usa,
# Nearest to nine: zero, two, one, three, five, eight, four, six,
# Nearest to to: modify, clinched, have, getting, gorgias, rectangular, imperiled, cci,
# Nearest to up: chordates, lesund, lowly, feats, households, size, departs, bpp,
# Nearest to there: sti, average, laura, just, someone, get, householder, enveloped,
# Nearest to most: such, noumenon, voroshilov, voluntary, mozilla, regulars, fulham, cumin,
# Nearest to animals: mammals, nesting, molluscs, reciprocation, subfamily, agave, taiga, vertebrates,
# Nearest to pressure: liveries, goya, refrigeration, adiabatic, tired, pleas, therefore, currents,
# Nearest to behind: quell, roundabout, swelling, kariba, jellyfish, overnight, situation, jaian,
# Nearest to discovered: vicissitudes, bubble, scandinavians, frederik, tariff, glaciations, bernicia, telemachus,
# Nearest to quite: continuants, homonyms, affordable, routines, rubbery, lignin, blows, whiteness,
# Nearest to derived: heritages, hedmark, tuscan, word, decomposition, anemones, msa, shank,
# Nearest to operating: trolltech, versions, exponential, freebsd, transmeta, installs, proprietary, workgroups,
# Nearest to shows: sissy, premiered, phineus, hamel, showings, coordinates, carmina, peri,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0021 0.4650 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9692 0.4620 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9954 0.4698 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0309 0.4556 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0370 0.4585 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9472 0.4600 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0011 0.4558 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0125 0.4513 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0136 0.4580 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9790 0.4568 sec/batch
# Nearest to see: culture, parseval, list, a, jpeg, may, ncipe, founded,
# Nearest to people: diuretic, incite, afer, hiv, basements, tabula, carnivorous, subdivision,
# Nearest to united: states, britain, hedy, secondhand, liberalisation, tomahawk, usa, ohio,
# Nearest to nine: one, two, three, zero, five, eight, six, four,
# Nearest to to: getting, modify, clinched, gorgias, have, rectangular, imperiled, themas,
# Nearest to up: chordates, lesund, households, lowly, cyndi, size, departs, bpp,
# Nearest to there: sti, average, laura, someone, just, get, martyrdom, wisely,
# Nearest to most: such, noumenon, voluntary, voroshilov, cumin, regulars, longstanding, fats,
# Nearest to animals: mammals, nesting, subfamily, molluscs, reciprocation, agave, taiga, vertebrates,
# Nearest to pressure: liveries, refrigeration, adiabatic, therefore, goya, pleas, tired, currents,
# Nearest to behind: quell, roundabout, swelling, overnight, kariba, rudy, jellyfish, delegated,
# Nearest to discovered: vicissitudes, bubble, scandinavians, frederik, telemachus, tariff, bernicia, ignited,
# Nearest to quite: continuants, affordable, homonyms, routines, rubbery, asynchronous, utilitarians, conflicts,
# Nearest to derived: heritages, tuscan, hedmark, word, msa, decomposition, kashubian, shank,
# Nearest to operating: trolltech, versions, exponential, transmeta, gyroscope, ewing, workgroups, freebsd,
# Nearest to shows: sissy, showings, hamel, premiered, phineus, carmina, coordinates, deleting,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0074 0.4606 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9832 0.4544 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9825 0.5040 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0107 0.4897 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0424 0.4964 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9952 0.5004 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9501 0.4685 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9553 0.4938 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9777 0.4881 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0043 0.4971 sec/batch
# Nearest to see: list, culture, may, parseval, jpeg, disambiguation, a, ncipe,
# Nearest to people: hiv, incite, afer, diuretic, tabula, repayments, ncs, poorer,
# Nearest to united: states, britain, liberalisation, secondhand, hedy, usa, ohio, tomahawk,
# Nearest to nine: one, two, zero, three, five, eight, four, six,
# Nearest to to: modify, getting, have, imperiled, clinched, ratify, and, gorgias,
# Nearest to up: lesund, bpp, households, size, chordates, departs, lowly, ramjet,
# Nearest to there: sti, average, laura, armenian, just, spread, householder, martyrdom,
# Nearest to most: such, noumenon, voluntary, voroshilov, mozilla, fats, has, cumin,
# Nearest to animals: nesting, mammals, subfamily, reciprocation, molluscs, agave, taiga, bermontians,
# Nearest to pressure: liveries, goya, pleas, tired, refrigeration, imposed, adiabatic, therefore,
# Nearest to behind: quell, roundabout, overnight, delegated, rudy, swelling, excavators, quadrivium,
# Nearest to discovered: vicissitudes, bubble, scandinavians, frederik, tariff, telemachus, goldsmith, inelastic,
# Nearest to quite: continuants, affordable, homonyms, routines, whiteness, asynchronous, utilitarians, rubbery,
# Nearest to derived: heritages, tuscan, word, hedmark, msa, redox, shank, decomposition,
# ...
# Nearest to see: links, list, a, disambiguation, references, also, may, defined,
# Nearest to people: hiv, such, geosynchronous, tantra, afer, mexican, natives, repayments,
# Nearest to united: states, britain, tomahawk, u, hedy, usa, legrand, america,
# Nearest to nine: one, three, two, five, zero, four, six, eight,
# Nearest to to: in, have, and, a, the, for, by, it,
# Nearest to up: together, from, with, households, size, out, dragonfly, rocker,
# Nearest to there: are, have, spread, householder, just, alone, sti, enveloped,
# Nearest to most: in, and, has, such, for, the, many, is,
# Nearest to animals: nesting, slaughtering, mares, molluscs, ungulates, jouvenel, hamilcar, norad,
# Nearest to pressure: liveries, refrigeration, dbv, embellishments, xvii, tenets, useable, adiabatic,
# Nearest to behind: roundabout, overnight, swelling, rudy, lapd, honda, backboard, vindicate,
# Nearest to discovered: vicissitudes, discoverer, bubble, later, scandinavians, rif, was, hominid,
# Nearest to quite: affordable, whiteness, continuants, nermal, pang, phillies, homonyms, para,
# Nearest to derived: word, decomposition, tert, directly, differentiate, but, larmor, become,
# Nearest to operating: trolltech, versions, ritchie, xcode, acquires, unix, terraserver, micros,
# Nearest to shows: premiered, at, pathologies, ceefax, showing, show, showings, syndication,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7937 0.4426 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8837 0.4355 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8299 0.4356 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8516 0.4414 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8735 0.4340 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8604 0.4385 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8671 0.4592 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8586 0.4519 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8733 0.4467 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8819 0.4390 sec/batch
# Nearest to see: links, a, list, disambiguation, and, may, external, references,
# Nearest to people: hiv, such, tantra, mexican, afer, natives, repayments, transgender,
# Nearest to united: states, britain, tomahawk, legrand, u, hedy, us, america,
# Nearest to nine: one, zero, two, three, five, four, six, eight,
# Nearest to to: have, and, the, in, a, for, with, by,
# Nearest to up: from, together, households, rocker, size, spread, householder, that,
# Nearest to there: are, have, spread, householder, just, alone, sti, identical,
# Nearest to most: in, and, such, has, the, one, for, many,
# Nearest to animals: nesting, mares, slaughtering, molluscs, hamilcar, ungulates, jouvenel, amphibians,
# Nearest to pressure: liveries, refrigeration, xvii, embellishments, dbv, useable, adiabatic, tenets,
# Nearest to behind: roundabout, overnight, swelling, rudy, lapd, vindicate, quell, honda,
# Nearest to discovered: vicissitudes, discoverer, bubble, later, rif, was, scandinavians, hominid,
# Nearest to quite: affordable, whiteness, continuants, nermal, para, pallavas, homonyms, pang,
# Nearest to derived: word, tert, but, decomposition, directly, incorrectly, differentiate, judgments,
# Nearest to operating: trolltech, versions, ritchie, acquires, terraserver, xcode, joking, sovereignty,
# Nearest to shows: at, show, premiered, ceefax, showing, pathologies, syndication, showings,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8604 0.4443 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8558 0.4351 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8447 0.4374 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8200 0.4417 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9105 0.4394 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8549 0.4370 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9601 0.4368 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8586 0.4528 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9138 0.4364 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8054 0.4378 sec/batch
# Nearest to see: links, list, a, external, by, disambiguation, references, may,
# Nearest to people: such, hiv, natives, repayments, mexican, transgender, afer, demographics,
# Nearest to united: states, britain, tomahawk, u, us, hedy, legrand, usa,
# Nearest to nine: one, two, three, zero, five, four, six, eight,
# Nearest to to: in, and, have, the, by, with, a, of,
# Nearest to up: from, together, that, rocker, with, vans, households, parted,
# Nearest to there: are, have, spread, householder, sti, just, alone, even,
# Nearest to most: in, and, such, has, one, the, many, of,
# Nearest to animals: nesting, slaughtering, hamilcar, mares, ungulates, molluscs, jouvenel, norad,
# Nearest to pressure: liveries, xvii, embellishments, dbv, refrigeration, useable, tenets, outlays,
# Nearest to behind: roundabout, overnight, swelling, vindicate, lapd, rudy, quell, backboard,
# Nearest to discovered: vicissitudes, discoverer, later, bubble, rif, was, erectus, hominid,
# Nearest to quite: affordable, whiteness, continuants, nermal, para, phillies, frasier, pallavas,
# Nearest to derived: word, tert, decomposition, directly, heritages, differentiate, but, incorrectly,
# Nearest to operating: trolltech, ritchie, versions, terraserver, acquires, xcode, joking, dani,
# Nearest to shows: at, premiered, show, ceefax, journalism, pathologies, showings, wlw,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8015 0.4484 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8568 0.4409 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7882 0.4396 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.9074 0.4568 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8438 0.4407 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8710 0.4376 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8622 0.2872 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8510 0.4366 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8227 0.4399 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8632 0.4375 sec/batch
# Nearest to see: links, list, disambiguation, external, a, may, references, by,
# Nearest to people: natives, such, hiv, geosynchronous, repayments, mexican, tantra, transgender,
# Nearest to united: states, britain, u, tomahawk, us, pentagon, hedy, legrand,
# Nearest to nine: one, three, two, five, zero, four, eight, six,
# Nearest to to: in, and, a, the, have, for, of, by,
# Nearest to up: from, with, together, rocker, households, that, householder, size,
# Nearest to there: are, have, just, sti, householder, even, spread, enveloped,
# Nearest to most: has, in, and, such, many, for, one, the,
# Nearest to animals: nesting, slaughtering, hamilcar, mares, norad, ungulates, jouvenel, richie,
# Nearest to pressure: liveries, dbv, xvii, refrigeration, embellishments, useable, adiabatic, pf,
# Nearest to behind: roundabout, overnight, backboard, lapd, swelling, rudy, vultures, excavators,
# Nearest to discovered: discoverer, later, was, vicissitudes, rif, bubble, erectus, that,
# Nearest to quite: affordable, whiteness, continuants, para, spouts, pallavas, nermal, utilitarians,
# Nearest to derived: word, tert, heritages, directly, incorrectly, but, decomposition, lantern,
# Nearest to operating: trolltech, versions, ritchie, terraserver, acquires, xcode, unix, joking,
# Nearest to shows: premiered, show, ceefax, at, pathologies, journalism, methods, wlw,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8020 0.4465 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8625 0.4556 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7898 0.4372 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8380 0.4432 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8583 0.4380 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8421 0.4406 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8654 0.4389 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7242 0.4412 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8353 0.4370 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7854 0.4417 sec/batch
# Nearest to see: links, list, a, external, by, disambiguation, may, references,
# Nearest to people: mexican, such, hiv, demographics, natives, geosynchronous, living, repayments,
# Nearest to united: states, britain, u, tomahawk, us, pentagon, nations, hedy,
# Nearest to nine: one, three, two, zero, five, four, six, eight,
# Nearest to to: a, in, the, for, and, have, by, of,
# Nearest to up: from, rocker, together, out, householder, households, them, someone,
# Nearest to there: are, have, just, even, sti, householder, spread, alone,
# Nearest to most: and, in, has, such, for, many, the, one,
# Nearest to animals: slaughtering, nesting, body, hamilcar, norad, ungulates, molluscs, amphibians,
# Nearest to pressure: liveries, xvii, refrigeration, embellishments, dbv, useable, pf, kwanza,
# Nearest to behind: roundabout, overnight, lapd, backboard, rudy, swelling, vindicate, vultures,
# Nearest to discovered: discoverer, later, vicissitudes, bubble, rif, erectus, presently, hominid,
# Nearest to quite: affordable, whiteness, continuants, phillies, para, spouts, pallavas, frasier,
# Nearest to derived: word, tert, incorrectly, but, directly, differentiate, decomposition, larmor,
# Nearest to operating: trolltech, versions, ritchie, acquires, terraserver, xcode, unix, exponential,
# Nearest to shows: at, premiered, show, pathologies, ceefax, syndication, methods, wlw,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7968 0.4439 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8408 0.4365 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8349 0.4350 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8386 0.4354 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8495 0.4417 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9161 0.4360 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8168 0.4362 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8192 0.4430 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8131 0.4347 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8270 0.4355 sec/batch
# Nearest to see: links, a, list, external, may, references, also, and,
# Nearest to people: mexican, hiv, natives, such, demographics, living, transgender, subdivision,
# Nearest to united: states, britain, u, us, tomahawk, nations, pentagon, hedy,
# Nearest to nine: one, two, three, five, zero, four, eight, six,
# Nearest to to: a, in, the, for, have, and, by, it,
# Nearest to up: from, together, rocker, households, them, with, out, someone,
# Nearest to there: are, have, alone, even, spread, householder, plowed, just,
# Nearest to most: in, and, has, for, such, many, the, of,
# Nearest to animals: nesting, slaughtering, hamilcar, ungulates, body, molluscs, amphibians, norad,
# Nearest to pressure: liveries, embellishments, xvii, refrigeration, dbv, useable, pf, adiabatic,
# Nearest to behind: roundabout, vindicate, backboard, overnight, rudy, lapd, swelling, vultures,
# Nearest to discovered: discoverer, bubble, rif, later, vicissitudes, was, erectus, presently,
# Nearest to quite: affordable, whiteness, para, phillies, continuants, nermal, pallavas, spouts,
# Nearest to derived: word, tert, incorrectly, differentiate, larmor, usage, directly, inexact,
# Nearest to operating: trolltech, versions, ritchie, acquires, terraserver, xcode, unix, joking,
# Nearest to shows: at, show, pathologies, premiered, ceefax, wlw, showing, nucleophilic,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8606 0.4402 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8704 0.4417 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8291 0.4365 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8385 0.4413 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8654 0.4366 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8635 0.4377 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8378 0.4355 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8308 0.4366 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8306 0.4570 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8238 0.4354 sec/batch
# Nearest to see: links, list, a, and, may, external, also, by,
# Nearest to people: natives, such, hiv, demographics, transgender, mexican, especially, native,
# Nearest to united: states, britain, u, tomahawk, us, nations, america, legrand,
# Nearest to nine: one, two, three, zero, five, four, eight, seven,
# Nearest to to: and, for, the, a, in, have, by, which,
# Nearest to up: from, together, with, rocker, that, households, vans, three,
# Nearest to there: are, have, even, spread, alone, just, sti, householder,
# Nearest to most: and, in, for, such, has, many, the, one,
# Nearest to animals: nesting, slaughtering, mares, molluscs, hamilcar, ungulates, amphibians, body,
# Nearest to pressure: liveries, xvii, embellishments, refrigeration, dbv, useable, pf, kwanza,
# Nearest to behind: roundabout, vindicate, overnight, lapd, rudy, swelling, backboard, vultures,
# Nearest to discovered: discoverer, later, vicissitudes, bubble, rif, erectus, was, presently,
# Nearest to quite: affordable, whiteness, para, phillies, continuants, nermal, pallavas, ekaterina,
# Nearest to derived: tert, word, incorrectly, but, differentiate, directly, larmor, usage,
# Nearest to operating: trolltech, versions, ritchie, terraserver, xcode, acquires, unix, joking,
# Nearest to shows: show, at, premiered, pathologies, ceefax, wlw, nucleophilic, syndication,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8551 0.4443 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8347 0.4467 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9454 0.4486 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8703 0.4451 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8981 0.4584 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8077 0.4398 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7815 0.4361 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8373 0.4385 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7757 0.4412 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8787 0.4395 sec/batch
# Nearest to see: links, list, a, and, by, external, also, disambiguation,
# Nearest to people: natives, living, mexican, transgender, hiv, demographics, especially, geosynchronous,
# Nearest to united: states, u, us, britain, tomahawk, hedy, legrand, nations,
# Nearest to nine: one, two, three, zero, four, five, eight, seven,
# Nearest to to: a, in, the, and, for, have, with, by,
# Nearest to up: from, with, rocker, that, together, giving, households, out,
# Nearest to there: are, have, spread, alone, even, sti, just, plowed,
# Nearest to most: and, has, in, such, the, for, many, of,
# Nearest to animals: slaughtering, nesting, mares, richie, hamilcar, body, norad, molluscs,
# Nearest to pressure: liveries, xvii, embellishments, refrigeration, dbv, useable, patriotic, methodology,
# Nearest to behind: roundabout, overnight, lapd, backboard, vindicate, swelling, rudy, buber,
# Nearest to discovered: discoverer, bubble, later, vicissitudes, rif, was, erectus, presently,
# Nearest to quite: whiteness, affordable, continuants, para, phillies, nermal, pallavas, frasier,
# Nearest to derived: tert, word, incorrectly, differentiate, but, directly, usage, inexact,
# Nearest to operating: trolltech, versions, ritchie, terraserver, xcode, unix, acquires, xdsl,
# Nearest to shows: show, pathologies, ceefax, premiered, at, nucleophilic, wlw, has,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8538 0.4432 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8164 0.4451 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
